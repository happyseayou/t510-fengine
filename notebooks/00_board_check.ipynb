# %% [markdown]
# # 00 Board Check
#
# Load the overlay and confirm the control/status plane is reachable.

# %%
from python.t510_fengine import T510FEngine

feng = T510FEngine("t510_fengine.bit")
feng.read_status()
