# %% [markdown]
# # 02 RFDC Snapshot
#
# Reserved for short DMA-based snapshots once the snapshot path is wired.

# %%
try:
    feng.snapshot(nsamp=65536)
except NotImplementedError as exc:
    print(exc)
