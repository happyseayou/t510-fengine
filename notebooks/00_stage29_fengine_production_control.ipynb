# %% [markdown]
# # Stage 29 F-engine Production Control + Preview
#
# This is the only production notebook. It loads the tested Stage 29 control module and keeps the frozen `CORE_VERSION=0x00010030` hardware/wire contract.

# %%
from pathlib import Path
import os
import sys
from IPython.display import display

os.environ.setdefault('XILINX_XRT', '/usr')
candidates = [
    Path.cwd().resolve(),
    Path.cwd().resolve().parent,
    Path('/home/xilinx/jupyter_notebooks/t510_fengine'),
    Path('/home/xilinx/t510_fengine_bringup'),
    Path('/home/astrolab/demo-ant'),
]
PROJECT_ROOT = next((root for root in candidates if (root / 'overlay/t510_fengine.bit').exists() and (root / 'python/stage29_console.py').exists()), None)
if PROJECT_ROOT is None:
    raise FileNotFoundError('Stage 29 overlay and production Python module were not found')
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
from python.stage29_console import create_console
display(create_console(PROJECT_ROOT))
